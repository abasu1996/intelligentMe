# %%
# %pip install pandas
import pandas as pd

car_sales_df = pd.read_csv('car-sales.csv')
car_sales_df.head()
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)
car_sales_missing
# Out:
# C:\Users\animb\AppData\Local\Temp\ipykernel_14484\3330876521.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# ...

# %%
car_sales_missing["Colour"].fillna("Black",inplace=True)
car_sales_missing
# Out:
# C:\Users\animb\AppData\Local\Temp\ipykernel_14484\1122597400.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Colour"].fillna("Black",inplace=True)
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# ...

# %%
car_sales_missing.dropna(inplace=True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda  Black   92302.666667    4.0   $7,500

# %%
car_sales_missing.to_csv("car_sales_missing_dropped.csv")

# %% [markdown]
# Column from Series

# %%
seats_column = pd.Series([4,4,4,4])
seats_column
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# dtype: int64

# %%
car_sales_df["Seats"]=seats_column

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    4.0
# 1   Honda    Red          87899      4   $5,000.00    4.0
# 2  Toyota   Blue          32549      3   $7,000.00    4.0
# 3     BMW  Black          11179      5  $22,000.00    4.0
# 4  Nissan  White         213095      4   $3,500.00    NaN
# 5  Toyota  Green          99213      4   $4,500.00    NaN
# 6   Honda   Blue          45698      4   $7,500.00    NaN
# 7   Honda   Blue          54738      4   $7,000.00    NaN
# 8  Toyota  White          60000      4   $6,250.00    NaN
# 9  Nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales_df.fillna(5,inplace=True)

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  Toyota  White         150043      4   $4,000.00    4.0
# 1   Honda    Red          87899      4   $5,000.00    4.0
# 2  Toyota   Blue          32549      3   $7,000.00    4.0
# 3     BMW  Black          11179      5  $22,000.00    4.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0

# %% [markdown]
# Column from Python List

# %%
fuel_economy = [8.5,11,12,11.6,15,7.5,8,9,10,4.6]
car_sales_df["Fuel Economy per 100KM"] = fuel_economy

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  \
# 0  Toyota  White         150043      4   $4,000.00    4.0
# 1   Honda    Red          87899      4   $5,000.00    4.0
# 2  Toyota   Blue          32549      3   $7,000.00    4.0
# 3     BMW  Black          11179      5  $22,000.00    4.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0
#
#    Fuel Economy per 100KM
# 0                     8.5
# 1                    11.0
# 2                    12.0
# 3                    11.6
# 4                    15.0
# 5                     7.5
# 6                     8.0
# 7                     9.0
# 8                    10.0
# 9                     4.6

# %%
car_sales_df["Total Fuel Used (L)"] = car_sales_df["Fuel Economy per 100KM"] * car_sales_df["Odometer (KM)"] / 100
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  \
# 0  Toyota  White         150043      4   $4,000.00    4.0
# 1   Honda    Red          87899      4   $5,000.00    4.0
# 2  Toyota   Blue          32549      3   $7,000.00    4.0
# 3     BMW  Black          11179      5  $22,000.00    4.0
# 4  Nissan  White         213095      4   $3,500.00    5.0
# 5  Toyota  Green          99213      4   $4,500.00    5.0
# 6   Honda   Blue          45698      4   $7,500.00    5.0
# 7   Honda   Blue          54738      4   $7,000.00    5.0
# 8  Toyota  White          60000      4   $6,250.00    5.0
# 9  Nissan  White          31600      4   $9,700.00    5.0
#
#    Fuel Economy per 100KM  Total Fuel Used (L)
# 0                     8.5            12753.655
# 1                    11.0             9668.890
# 2                    12.0             3905.880
# 3                    11.6             1296.764
# 4                    15.0            31964.250
# ...

# %%
Markdown("Column from another column")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Markdown("Column from another column")
#
# NameError: name 'Markdown' is not defined

# %%
car_sales_df["Number of Wheels"] = 4
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  \
# 0  Toyota  White         150043      4   $4,000.00   4.0
# 1   Honda    Red          87899      4   $5,000.00   4.0
# 2  Toyota   Blue          32549      3   $7,000.00   4.0
# 3     BMW  Black          11179      5  $22,000.00   4.0
# 4  Nissan  White         213095      4   $3,500.00     5
# 5  Toyota  Green          99213      4   $4,500.00     5
# 6   Honda   Blue          45698      4   $7,500.00     5
# 7   Honda   Blue          54738      4   $7,000.00     5
# 8  Toyota  White          60000      4   $6,250.00     5
# 9  Nissan  White          31600      4   $9,700.00     5
#
#    Fuel Economy per 100KM  Total Fuel Used  Total Fuel Used (L)  \
# 0                     8.5        12753.655            12753.655
# 1                    11.0         9668.890             9668.890
# 2                    12.0         3905.880             3905.880
# 3                    11.6         1296.764             1296.764
# ...

# %%
car_sales_df["Passed Road Safety"] = True
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  \
# 0  Toyota  White         150043      4   $4,000.00   4.0
# 1   Honda    Red          87899      4   $5,000.00   4.0
# 2  Toyota   Blue          32549      3   $7,000.00   4.0
# 3     BMW  Black          11179      5  $22,000.00   4.0
# 4  Nissan  White         213095      4   $3,500.00     5
# 5  Toyota  Green          99213      4   $4,500.00     5
# 6   Honda   Blue          45698      4   $7,500.00     5
# 7   Honda   Blue          54738      4   $7,000.00     5
# 8  Toyota  White          60000      4   $6,250.00     5
# 9  Nissan  White          31600      4   $9,700.00     5
#
#    Fuel Economy per 100KM  Total Fuel Used  Total Fuel Used (L)  \
# 0                     8.5        12753.655            12753.655
# 1                    11.0         9668.890             9668.890
# 2                    12.0         3905.880             3905.880
# 3                    11.6         1296.764             1296.764
# ...

# %%
car_sales_df.dtypes
# Out:
# Make                       object
# Colour                     object
# Odometer (KM)               int64
# Doors                       int64
# Price                      object
# Seats                      object
# Fuel Economy per 100KM    float64
# Total Fuel Used           float64
# Total Fuel Used (L)       float64
# Number of Wheels            int64
# Passed Road Safety           bool
# dtype: object

# %%
car_sales_df.drop("Total Fuel Used (L)", axis=1, inplace=True)
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  \
# 0  Toyota  White         150043      4   $4,000.00   4.0
# 1   Honda    Red          87899      4   $5,000.00   4.0
# 2  Toyota   Blue          32549      3   $7,000.00   4.0
# 3     BMW  Black          11179      5  $22,000.00   4.0
# 4  Nissan  White         213095      4   $3,500.00     5
# 5  Toyota  Green          99213      4   $4,500.00     5
# 6   Honda   Blue          45698      4   $7,500.00     5
# 7   Honda   Blue          54738      4   $7,000.00     5
# 8  Toyota  White          60000      4   $6,250.00     5
# 9  Nissan  White          31600      4   $9,700.00     5
#
#    Fuel Economy per 100KM  Total Fuel Used  Number of Wheels  \
# 0                     8.5        12753.655                 4
# 1                    11.0         9668.890                 4
# 2                    12.0         3905.880                 4
# 3                    11.6         1296.764                 4
# ...

# %%
car_sales_missing.sample(frac=1)
# Out:
#      Make Colour       Odometer  Doors    Price
# 6   Honda  Black   92302.666667    4.0   $7,500
# 4  Nissan  White  213095.000000    4.0   $3,500
# 0  Toyota  White  150043.000000    4.0   $4,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 1   Honda    Red   87899.000000    4.0   $5,000

# %%
car_sales_df.sample(frac=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 car_sales_df.sample(frac=1,inplace=True)
#
# TypeError: NDFrame.sample() got an unexpected keyword argument 'inplace'. Did you mean 'replace'?

# %%
 car_sales_suffled = car_sales_df.sample(frac=1)

# %%
car_sales_suffled
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  \
# 5  Toyota  Green          99213      4   $4,500.00     5
# 7   Honda   Blue          54738      4   $7,000.00     5
# 0  Toyota  White         150043      4   $4,000.00   4.0
# 3     BMW  Black          11179      5  $22,000.00   4.0
# 4  Nissan  White         213095      4   $3,500.00     5
# 6   Honda   Blue          45698      4   $7,500.00     5
# 8  Toyota  White          60000      4   $6,250.00     5
# 1   Honda    Red          87899      4   $5,000.00   4.0
# 2  Toyota   Blue          32549      3   $7,000.00   4.0
# 9  Nissan  White          31600      4   $9,700.00     5
#
#    Fuel Economy per 100KM  Total Fuel Used  Number of Wheels  \
# 5                     7.5         7440.975                 4
# 7                     9.0         4926.420                 4
# 0                     8.5        12753.655                 4
# 3                    11.6         1296.764                 4
# ...

# %%
car_sales_suffled.sample(frac=0.001)
# Out:
# Empty DataFrame
# Columns: [Make, Colour, Odometer (KM), Doors, Price, Seats, Fuel Economy per 100KM, Total Fuel Used, Number of Wheels, Passed Road Safety]
# Index: []

# %%
car_sales_reset_index = car_sales_suffled.reset_index(drop=True)
car_sales_reset_index
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  \
# 0  Toyota  Green          99213      4   $4,500.00     5
# 1   Honda   Blue          54738      4   $7,000.00     5
# 2  Toyota  White         150043      4   $4,000.00   4.0
# 3     BMW  Black          11179      5  $22,000.00   4.0
# 4  Nissan  White         213095      4   $3,500.00     5
# 5   Honda   Blue          45698      4   $7,500.00     5
# 6  Toyota  White          60000      4   $6,250.00     5
# 7   Honda    Red          87899      4   $5,000.00   4.0
# 8  Toyota   Blue          32549      3   $7,000.00   4.0
# 9  Nissan  White          31600      4   $9,700.00     5
#
#    Fuel Economy per 100KM  Total Fuel Used  Number of Wheels  \
# 0                     7.5         7440.975                 4
# 1                     9.0         4926.420                 4
# 2                     8.5        12753.655                 4
# 3                    11.6         1296.764                 4
# ...

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  \
# 0  Toyota  White         150043      4   $4,000.00   4.0
# 1   Honda    Red          87899      4   $5,000.00   4.0
# 2  Toyota   Blue          32549      3   $7,000.00   4.0
# 3     BMW  Black          11179      5  $22,000.00   4.0
# 4  Nissan  White         213095      4   $3,500.00     5
# 5  Toyota  Green          99213      4   $4,500.00     5
# 6   Honda   Blue          45698      4   $7,500.00     5
# 7   Honda   Blue          54738      4   $7,000.00     5
# 8  Toyota  White          60000      4   $6,250.00     5
# 9  Nissan  White          31600      4   $9,700.00     5
#
#    Fuel Economy per 100KM  Total Fuel Used  Number of Wheels  \
# 0                     8.5        12753.655                 4
# 1                    11.0         9668.890                 4
# 2                    12.0         3905.880                 4
# 3                    11.6         1296.764                 4
# ...

# %%
car_sales_df["Odometer (KM)"] = car_sales_df["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_sales_df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price Seats  \
# 0  Toyota  White      93776.875      4   $4,000.00   4.0
# 1   Honda    Red      54936.875      4   $5,000.00   4.0
# 2  Toyota   Blue      20343.125      3   $7,000.00   4.0
# 3     BMW  Black       6986.875      5  $22,000.00   4.0
# 4  Nissan  White     133184.375      4   $3,500.00     5
# 5  Toyota  Green      62008.125      4   $4,500.00     5
# 6   Honda   Blue      28561.250      4   $7,500.00     5
# 7   Honda   Blue      34211.250      4   $7,000.00     5
# 8  Toyota  White      37500.000      4   $6,250.00     5
# 9  Nissan  White      19750.000      4   $9,700.00     5
#
#    Fuel Economy per 100KM  Total Fuel Used  Number of Wheels  \
# 0                     8.5        12753.655                 4
# 1                    11.0         9668.890                 4
# 2                    12.0         3905.880                 4
# 3                    11.6         1296.764                 4
# ...
